# %%
import pymongo
import pandas as pd
from pymongo import MongoClient as Connection
connection = Connection()
db = connection.recipe_db
input_data = db.rezepte
data = pd.DataFrame(list(input_data.find()))

# %%
data.dtypes

# %%
data.head()

# %%
# Method 1:
Sorted = data.sort_values(['made_it_count'], ascending=False)
Sorted.head(1)

# %%
data.shape

# %%
data.info

# %%
import json
from pandas.io.json import json_normalize
df = json_normalize(data)

# %%
import sys
sys.modules.keys()

# %%
find_loaded_modules().HTML

# %%
# !pip install pandas

# %%
pd.show_versions()

# %%
# !type -a python

# %%
import sys
print(sys.version)

# %%
json={
    
    "cook_time" : 15,
    "rating" : 4.637681,
    "description" : "These are the best fried pork chops you will ever eat. You can also try this with cube steak for chicken-fried steak, or with chicken breast!",
    "author" : "Rebecca Laymance",
    "url" : "https://www.allrecipes.com/recipe/155074/beccas-chicken-fried-pork-chops/",
    "ingredients" : [ 
        {
            "grams" : 187.5,
            "type" : "Normal",
            "id" : 1684,
            "name" : "190 g all-purpose flour"
        }, 
        {
            "grams" : 3.42124987,
            "type" : "Normal",
            "id" : 16404,
            "name" : "3 g ground paprika"
        }, 
        {
            "grams" : 1.38833332,
            "type" : "Normal",
            "id" : 16396,
            "name" : "1 g garlic powder"
        }, 
        {
            "grams" : 100.0,
            "type" : "Normal",
            "id" : 16317,
            "name" : "2 eggs"
        }, 
        {
            "grams" : 122.0,
            "type" : "Normal",
            "id" : 16278,
            "name" : "120 ml milk"
        }, 
        {
            "grams" : 224.0,
            "type" : "Normal",
            "id" : 2231,
            "name" : "0.5 (16 ounce) package saltine crackers, crushed"
        }, 
        {
            "grams" : 24.0,
            "type" : "Normal",
            "id" : 4457,
            "name" : "25 g dry potato flakes"
        }, 
        {
            "grams" : 62.5,
            "type" : "Normal",
            "id" : 1684,
            "name" : "60 g all-purpose flour"
        }, 
        {
            "grams" : 904.0,
            "type" : "Normal",
            "id" : 5306,
            "name" : "4 (3/4 inch) thick pork chops"
        }, 
        {
            "grams" : 0.4,
            "type" : "HideAmounts",
            "id" : 16421,
            "name" : "salt and pepper to taste"
        }, 
        {
            "grams" : 330.0,
            "type" : "Normal",
            "id" : 20482,
            "name" : "355 ml vegetable oil for frying"
        }
    ],
    "name" : "Becca's Chicken-Fried Pork Chops",
    "reviews" : [ 
        {
            "reviewer_name" : "foxyfoote",
            "reviewer_id" : 3795339,
            "reviewer_recipe_rating" : 4,
            "reviewer_recipe_made_count" : 1,
            "reviewer_favs" : 1
        }, 
        {
            "reviewer_name" : "Jane Guzauskas Ruby",
            "reviewer_id" : 2355486,
            "reviewer_recipe_rating" : 4,
            "reviewer_recipe_made_count" : 96,
            "reviewer_favs" : 23
        }, 
        {
            "reviewer_name" : "Bevarly",
            "reviewer_id" : 1946009,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 46,
            "reviewer_favs" : 267
        }, 
        {
            "reviewer_name" : "AppleJuice",
            "reviewer_id" : 3794239,
            "reviewer_recipe_rating" : 4,
            "reviewer_recipe_made_count" : 1,
            "reviewer_favs" : 0
        }, 
        {
            "reviewer_name" : "Jessica Lynne",
            "reviewer_id" : 5076267,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 3,
            "reviewer_favs" : 43
        }, 
        {
            "reviewer_name" : "shrimpstuffedmanicott",
            "reviewer_id" : 2913489,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" :

            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 1,
            "reviewer_favs" : 48
        }, 
        {
            "reviewer_name" : "jdawson4993",
            "reviewer_id" : 13064980,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 7,
            "reviewer_favs" : 31
        }, 
        {
            "reviewer_name" : "1964arrieta",
            "reviewer_id" : 11234211,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 6,
            "reviewer_favs" : 106
        }, 
        {
            "reviewer_name" : "lisa",
            "reviewer_id" : 8740521,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 1,
            "reviewer_favs" : 0
        }, 
        {
            "reviewer_name" : "Linda Tracer",
            "reviewer_id" : 3885396,
            "reviewer_recipe_rating" : 4,
            "reviewer_recipe_made_count" : 8,
            "reviewer_favs" : 229
        }, 
        {
            "reviewer_name" : "LydiaKJ",
            "reviewer_id" : 13227406,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 3,
            "reviewer_favs" : 2
        }, 
        {
            "reviewer_name" : "Donald Chadwick",
            "reviewer_id" : 15344711,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 7,
            "reviewer_favs" : 0
        }, 
        {
            "reviewer_name" : "Edward Filipino",
            "reviewer_id" : 20962607,
            "reviewer_recipe_rating" : 1,
            "reviewer_recipe_made_count" : 0,
            "reviewer_favs" : 138
        }, 
        {
            "reviewer_name" : "melanie",
            "reviewer_id" : 15369305,
            "reviewer_recipe_rating" : 4,
            "reviewer_recipe_made_count" : 3,
            "reviewer_favs" : 504
        }, 
        {
            "reviewer_name" : "Tamie Gayle",
            "reviewer_id" : 20437588,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 15,
            "reviewer_favs" : 76
        }, 
        {
            "reviewer_name" : "jenshep",
            "reviewer_id" : 21413921,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 20,
            "reviewer_favs" : 34
        }, 
        {
            "reviewer_name" : "MATENNIS",
            "reviewer_id" : 1247223,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 30,
            "reviewer_favs" : 81
        }, 
        {
            "reviewer_name" : "Jennifer Hall",
            "reviewer_id" : 16678683,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 5,
            "reviewer_favs" : 65
        }, 
        {
            "reviewer_name" : "LaVonna Mimz",
            "reviewer_id" : 16995921,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 9,
            "reviewer_favs" : 45
        }, 
        {
            "reviewer_name" : "ginger Antuna",
            "reviewer_id" : 15786426,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 16,
            "reviewer_favs" : 107
        }, 
        {
            "reviewer_name" : "sheryl",
            "reviewer_id" : 9288099,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 1,
            "reviewer_favs" : 105
        }, 
        {
            "reviewer_name" : "PugHugz",
            "reviewer_id" : 18264029,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 33,
            "reviewer_favs" : 416
        }, 
        {
            "reviewer_name" : "Megan",
            "reviewer_id" : 2062617,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 26,
            "reviewer_favs" : 232
        }, 
        {
            "reviewer_name" : "Lisa Lisa",
            "reviewer_id" : 15291933,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 1,
            "reviewer_favs" : 0
        }, 
        {
            "reviewer_name" : "edbrown",
            "reviewer_id" : 3018687,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 3,
            "reviewer_favs" : 38
        }, 
        {
            "reviewer_name" : "StaceyR",
            "reviewer_id" : 13232183,
            "reviewer_recipe_rating" : 4,
            "reviewer_recipe_made_count" : 4,
            "reviewer_favs" : 12
        }, 
        {
            "reviewer_name" : "Julie Iantosca Reid",
            "reviewer_id" : 2291833,
            "reviewer_recipe_rating" : 4,
            "reviewer_recipe_made_count" : 19,
            "reviewer_favs" : 544
        }, 
        {
            "reviewer_name" : "Elizabeth Heffernan",
            "reviewer_id" : 11299326,
            "reviewer_recipe_rating" : 3,
            "reviewer_recipe_made_count" : 25,
            "reviewer_favs" : 483
        }
    ]
}

# %%
from pandas.io.json import json_normalize
df =json_normalize(json)

# %%
json

# %%
df.head()

# %%
json2={
    
    "cook_time" : 15,
    "rating" : 4.637681,
    "description" : "These are the best fried pork chops you will ever eat. You can also try this with cube steak for chicken-fried steak, or with chicken breast!",
    "author" : "Rebecca Laymance",
    "url" : "https://www.allrecipes.com/recipe/155074/beccas-chicken-fried-pork-chops/",
    "ingredients" : [ 
        {
            "grams" : 187.5,
            "type" : "Normal",
            "id" : 1684,
            "name" : "190 g all-purpose flour"
        }, 
        {
            "grams" : 3.42124987,
            "type" : "Normal",
            "id" : 16404,
            "name" : "3 g ground paprika"
        }, 
        {
            "grams" : 1.38833332,
            "type" : "Normal",
            "id" : 16396,
            "name" : "1 g garlic powder"
        }, 
        {
            "grams" : 100.0,
            "type" : "Normal",
            "id" : 16317,
            "name" : "2 eggs"
        }, 
        {
            "grams" : 122.0,
            "type" : "Normal",
            "id" : 16278,
            "name" : "120 ml milk"
        }, 
        {
            "grams" : 224.0,
            "type" : "Normal",
            "id" : 2231,
            "name" : "0.5 (16 ounce) package saltine crackers, crushed"
        }, 
        {
            "grams" : 24.0,
            "type" : "Normal",
            "id" : 4457,
            "name" : "25 g dry potato flakes"
        }, 
        {
            "grams" : 62.5,
            "type" : "Normal",
            "id" : 1684,
            "name" : "60 g all-purpose flour"
        }, 
        {
            "grams" : 904.0,
            "type" : "Normal",
            "id" : 5306,
            "name" : "4 (3/4 inch) thick pork chops"
        }, 
        {
            "grams" : 0.4,
            "type" : "HideAmounts",
            "id" : 16421,
            "name" : "salt and pepper to taste"
        }, 
        {
            "grams" : 330.0,
            "type" : "Normal",
            "id" : 20482,
            "name" : "355 ml vegetable oil for frying"
        }
    ],
    "name" : "Becca's Chicken-Fried Pork Chops",
    "reviews" : [ 
        {
            "reviewer_name" : "foxyfoote",
            "reviewer_id" : 3795339,
            "reviewer_recipe_rating" : 4,
            "reviewer_recipe_made_count" : 1,
            "reviewer_favs" : 1
        }, 
        {
            "reviewer_name" : "Jane Guzauskas Ruby",
            "reviewer_id" : 2355486,
            "reviewer_recipe_rating" : 4,
            "reviewer_recipe_made_count" : 96,
            "reviewer_favs" : 23
        }, 
        {
            "reviewer_name" : "Bevarly",
            "reviewer_id" : 1946009,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 46,
            "reviewer_favs" : 267
        }, 
        {
            "reviewer_name" : "AppleJuice",
            "reviewer_id" : 3794239,
            "reviewer_recipe_rating" : 4,
            "reviewer_recipe_made_count" : 1,
            "reviewer_favs" : 0
        }, 
        {
            "reviewer_name" : "Jessica Lynne",
            "reviewer_id" : 5076267,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 3,
            "reviewer_favs" : 43
        }, 
        {
            "reviewer_name" : "shrimpstuffedmanicott",
            "reviewer_id" : 2913489,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 11,
            "reviewer_favs" : 139
        }, 
        {
            "reviewer_name" : "breezyauzette",
            "reviewer_id" : 4697916,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 9,
            "reviewer_favs" : 126
        }, 
        {
            "reviewer_name" : "Grumpygrandpa",
            "reviewer_id" : 11113834,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 9,
            "reviewer_favs" : 136
        }, 
        {
            "reviewer_name" : "Chelsea Rice",
            "reviewer_id" : 3579897,
            "reviewer_recipe_rating" : 3,
            "reviewer_recipe_made_count" : 58,
            "reviewer_favs" : 288
        }, 
        {
            "reviewer_name" : "BECCAP",
            "reviewer_id" : 1405774,
            "reviewer_recipe_rating" : 4,
            "reviewer_recipe_made_count" : 407,
            "reviewer_favs" : 12
        }, 
        {
            "reviewer_name" : "90%ornothing",
            "reviewer_id" : 7230264,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 23,
            "reviewer_favs" : 129
        }, 
        {
            "reviewer_name" : "Jesse L",
            "reviewer_id" : 4521391,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" :

            "reviewer_recipe_rating" : 4,
            "reviewer_recipe_made_count" : 3,
            "reviewer_favs" : 504
        }, 
        {
            "reviewer_name" : "Tamie Gayle",
            "reviewer_id" : 20437588,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 15,
            "reviewer_favs" : 76
        }, 
        {
            "reviewer_name" : "jenshep",
            "reviewer_id" : 21413921,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 20,
            "reviewer_favs" : 34
        }, 
        {
            "reviewer_name" : "MATENNIS",
            "reviewer_id" : 1247223,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 30,
            "reviewer_favs" : 81
        }, 
        {
            "reviewer_name" : "Jennifer Hall",
            "reviewer_id" : 16678683,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 5,
            "reviewer_favs" : 65
        }, 
        {
            "reviewer_name" : "LaVonna Mimz",
            "reviewer_id" : 16995921,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 9,
            "reviewer_favs" : 45
        }, 
        {
            "reviewer_name" : "ginger Antuna",
            "reviewer_id" : 15786426,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 16,
            "reviewer_favs" : 107
        }, 
        {
            "reviewer_name" : "sheryl",
            "reviewer_id" : 9288099,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 1,
            "reviewer_favs" : 105
        }, 
        {
            "reviewer_name" : "PugHugz",
            "reviewer_id" : 18264029,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 33,
            "reviewer_favs" : 416
        }, 
        {
            "reviewer_name" : "Megan",
            "reviewer_id" : 2062617,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 26,
            "reviewer_favs" : 232
        }, 
        {
            "reviewer_name" : "Lisa Lisa",
            "reviewer_id" : 15291933,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 1,
            "reviewer_favs" : 0
        }, 
        {
            "reviewer_name" : "edbrown",
            "reviewer_id" : 3018687,
            "reviewer_recipe_rating" : 5,
            "reviewer_recipe_made_count" : 3,
            "reviewer_favs" : 38
        }, 
        {
            "reviewer_name" : "StaceyR",
            "reviewer_id" : 13232183,
            "reviewer_recipe_rating" : 4,
            "reviewer_recipe_made_count" : 4,
            "reviewer_favs" : 12
        }, 
        {
            "reviewer_name" : "Julie Iantosca Reid",
            "reviewer_id" : 2291833,
            "reviewer_recipe_rating" : 4,
            "reviewer_recipe_made_count" : 19,
            "reviewer_favs" : 544
        }, 
        {
            "reviewer_name" : "Elizabeth Heffernan",
            "reviewer_id" : 11299326,
            "reviewer_recipe_rating" : 3,
            "reviewer_recipe_made_count" : 25,
            "reviewer_favs" : 483
        }
    ],
    "authorId" : 1563072,
    "rating_count" : 69,
    "ready_in_time" : 35,
    "categories" : [ 
        {
            "name" : "Southern"
        }, 
        {
            "name" : "Pork"
        }, 
        {
            "name" : "Chicken"
        }, 
        {
            "name" : "World"
        }, 
        {
            "name" : "Main"
        }, 
        {
            "name" : "Dinner"
        }
    ],
    "prep_time" : 20,
    "servings" : 4,
    "review_count" : 51,
    "made_it_count" : 211,
    "id" : 155074,
    "nutritions" : [ 
        {
            "percent_daily_value" : "45",
            "amount" : 29.17648,
            "name" : "Fat",
            "unit" : "g",
            "display_value" : "29.2"
        }, 
        {
            "percent_daily_value" : "42",
            "amount" : 831.2492,
            "name" : "Calories",
            "unit" : "kcal",
            "display_value" : "831"
        }, 
        {
            "percent_daily_value" : "55",
            "amount" : 164.565,
            "name" : "Cholesterol",
            "unit" : "mg",
            "display_value" : "165"
        }, 
        {
            "percent_daily_value" : "28",
            "amount" : 707.0461,
            "name" : "Sodium",
            "unit" : "mg",
            "display_value" : "707"
        }, 
        {
            "percent_daily_value" : "31",
            "amount" : 94.62257,
            "name" : "Carbohydrates",
            "unit" : "g",
            "display_value" : "94.6"
        }, 
        {
            "percent_daily_value" : "88",
            "amount" : 44.21453,
            "name" : "Protein",
            "unit" : "g",
            "display_value" : "44.2"
        }, 
        {
            "percent_daily_value" : "118",
            "amount" : 212.1261,
            "name" : "Folate",
            "unit" : "mcg",
            "display_value" : "212"
        }, 
        {
            "percent_daily_value" : "23",
            "amount" : 64.83114,
            "name" : "Magnesium",
            "unit" : "mg",
            "display_value" : "65"
        }, 
        {
            "percent_daily_value" : "38",
            "amount" : 0.6054628,
            "name" : "Vitamin B6",
            "unit" : "mg",
            "display_value" : "< 1"
        }, 
        {
            "percent_daily_value" : "172",
            "amount" : 22.32211,
            "name" : "Niacin Equivalents",
            "unit" : "mg",
            "display_value" : "22"
        }, 
        {
            "percent_daily_value" : "176",
            "amount" : 1.758589,
            "name" : "Thiamin",
            "unit" : "mg",
            "display_value" : "2"
        }, 
        {
            "percent_daily_value" : "76",
            "amount" : 7.569338,
            "name" : "Iron",
            "unit" : "mg",
            "display_value" : "8"
        }, 
        {
            "percent_daily_value" : "15",
            "amount" : 119.5516,
            "name" : "Calcium",
            "unit" : "mg",
            "display_value" : "120"
        }, 
        {
            "percent_daily_value" : "10",
            "amount" : 5.887852,
            "name" : "Vitamin C",
            "unit" : "mg",
            "display_value" : "6"
        }, 
        {
            "percent_daily_value" : "13",
            "amount" : 637.029,
            "name" : "Vitamin A - IU",
            "unit" : "IU",
            "display_value" : "637"
        }, 
        {
            "percent_daily_value" : "0",
            "amount" : 2.375831,
            "name" : "Sugars",
            "unit" : "g",
            "display_value" : "2.4"
        }, 
        {
            "percent_daily_value" : "22",
            "amount" : 771.4274,
            "name" : "Potassium",
            "unit" : "mg",
            "display_value" : "771"
        }, 
        {
            "percent_daily_value" : "36",
            "amount" : 7.18894,
            "name" : "Saturated Fat",
            "unit" : "g",
            "display_value" : "7.2"
        }, 
        {
            "percent_daily_value" : "-",
            "amount" : 262.5883,
            "name" : "Calories from Fat",
            "unit" : "kcal",
            "display_value" : "263"
        }, 
        {
            "percent_daily_value" : "16",
            "amount" : 4.117748,
            "name" : "Dietary Fiber",
            "unit" : "g",
            "display_value" : "4.1"
        }
    ],
    "api_url" : "https://apps.allrecipes.com/v1/recipes/155074"
}

# %%
df2 = json_normalize(json2)

# %%
df2.head()

# %%
import pandas as pd
from bson import json_util, ObjectId
from pandas.io.json import json_normalize
import json

# %%
import pymongo
import pandas as pd
from pymongo import MongoClient as Connection
connection = Connection()
db = connection.recipe_db
#input_data = db.rezepte
#data = pd.DataFrame(list(input_data.find()))

sanitized = json.loads(json_util.dumps(input_data.find()))
normalized = json_normalize(sanitized)
df = pd.DataFrame(normalized)

# %%
df.head()

# %%
import pymongo
import pandas as pd
from pymongo import MongoClient as Connection
connection = Connection()
db = connection.recipe_db
#input_data = db.rezepte
#data = pd.DataFrame(list(input_data.find()))

data = json.loads(json_util.dumps(input_data.find()))

normalized = json_normalize(sanitized, 'ingredients', ['grams', 'type', 'id', 'name'], record_prefix='ing_', errors='ignore' )
df = pd.DataFrame(normalized)
df.head()

# %%
df.head(50)

# %%
j = {
    "number": "",
    "date": "01.10.2016",
    "name": "R 3932",
    "locations": [
        {
            "depTimeDiffMin": "0",
            "name": "Spital am Pyhrn Bahnhof",
            "arrTime": "",
            "depTime": "06:32",
            "platform": "2",
            "stationIdx": "0",
            "arrTimeDiffMin": "",
            "track": "R 3932"
        },
        {
            "depTimeDiffMin": "0",
            "name": "Windischgarsten Bahnhof",
            "arrTime": "06:37",
            "depTime": "06:40",
            "platform": "2",
            "stationIdx": "1",
            "arrTimeDiffMin": "1",
            "track": ""
        },
        {
            "depTimeDiffMin": "",
            "name": "Linz/Donau Hbf",
            "arrTime": "08:24",
            "depTime": "",
            "platform": "1A-B",
            "stationIdx": "22",
            "arrTimeDiffMin": "1",
            "track": ""
        }
    ]
}

import json
from pandas.io.json import json_normalize    


#data = json.load(j)  

df = json_normalize(j, 'locations', ['date', 'number', 'name'], 
                    record_prefix='locations_')
df.head()

# %%
import json
from pandas.io.json import json_normalize    
import pymongo
import pandas as pd
from pymongo import MongoClient as Connection
connection = Connection()
db = connection.recipe_db
#input_data = db.rezepte
#data = pd.DataFrame(list(input_data.find()))

data = json.loads(json_util.dumps(input_data.find()))
norm_data = json_normalize(data)

# %%
ingredients = json_normalize(data, record_path='ingredients', meta='id', record_prefix='ingredients.', errors='ignore' )
ingredients = pd.DataFrame(ingredients)
ingredients.head()

# %%
reviews = json_normalize(data, record_path='reviews', meta='id', record_prefix='review.', errors='ignore' )
reviews = pd.DataFrame(reviews)
reviews.head()

# %%
norm_data.columns

# %%
#norm_data_cleaned = norm_data

#Spaltenindex ausgeben
norm_data.columns.get_loc('_id.$oid')

# %%
#Lösche nicht benötigte Splaten

norm_data_cleaned.drop(norm_data_cleaned.columns[[0, 4, 8, 11, 17]], axis=1, inplace=True)

# %%
norm_data_cleaned.columns
norm_data_cleaned.head()

# %%
categories = json_normalize(data, record_path='categories', meta='id', record_prefix='categories.', errors='ignore' )
categories = pd.DataFrame(categories)
categories.head()

# %%
len(norm_data_cleaned.set_index('id').index.get_duplicates())

#norm_data_cleaned.drop_duplicates()

norm_data_cleaned.shape

# %%
type(norm_data_cleaned.id.duplicated())
norm_data_cleaned.id.duplicated().sum()

bla = norm_data_cleaned.drop_duplicates(keep='first')
bla.id.duplicated().sum()
bla.shape

# %%
#all_categories = pd.merge(categories, norm_data_cleaned, how='inner', on='id')

#len(df.columns) 

norm_data_cleaned.loc[norm_data_cleaned.duplicated(), :]

# %%
all_categories.head(100)
